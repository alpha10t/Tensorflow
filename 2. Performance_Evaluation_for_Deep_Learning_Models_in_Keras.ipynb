# %%
# !wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv

# %% [markdown]
# #Use an Automatic Verification Dataset
# Keras can separate a portion of your training data into a validation dataset and evaluate the performance of your model on that validation dataset in each epoch.
#
# You can do this by setting the validation_split argument on the fit() function to a percentage of the size of your training dataset.
#
# For example, a reasonable value might be 0.2 or 0.33 for 20% or 33% of your training data held back for validation.
#
# The example below demonstrates the use of an automatic validation dataset on a small binary classification problem. All examples in this post use the Pima Indians onset of diabetes dataset. You can download it from the UCI Machine Learning Repository and save the data file in your current working directory with the filename pima-indians-diabetes.csv.

# %%
# MLP with automatic validation set
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10)

# %% [markdown]
# #Use a Manual Verification Dataset
# Keras also allows you to manually specify the dataset to use for validation during training.
#
# In this example, you can use the handy train_test_split() function from the Python scikit-learn machine learning library to separate your data into a training and test dataset. Use 67% for training and the remaining 33% of the data for validation.
#
# The validation dataset can be specified to the fit() function in Keras by the validation_data argument. It takes a tuple of the input and output datasets.

# %%
# MLP with manual validation set
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# split into 67% for train and 33% for test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=seed)
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 52/52 [==============================] - 2s 9ms/step - loss: 6.2527 - accuracy: 0.3521 - val_loss: 1.6058 - val_accuracy: 0.3976
# Epoch 2/150
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1452 - accuracy: 0.4222 - val_loss: 0.8576 - val_accuracy: 0.4724
# Epoch 3/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.8115 - accuracy: 0.5097 - val_loss: 0.8767 - val_accuracy: 0.5315
# Epoch 4/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7738 - accuracy: 0.5817 - val_loss: 0.7365 - val_accuracy: 0.5906
# Epoch 5/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7322 - accuracy: 0.6265 - val_loss: 0.7226 - val_accuracy: 0.6142
# Epoch 6/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.7127 - accuracy: 0.6284 - val_loss: 0.7114 - val_accuracy: 0.6535
# Epoch 7/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6964 - accuracy: 0.6381 - val_loss: 0.7152 - val_accuracy: 0.6457
# Epoch 8/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.6342 - val_loss: 0.7074 - val_accuracy: 0.6417
# Epoch 9/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.6479 - val_loss: 0.6961 - val_accuracy: 0.6496
# Epoch 10/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.6479 - val_loss: 0.6971 - val_accuracy: 0.6496
# Epoch 11/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6687 - accuracy: 0.6556 - val_loss: 0.6966 - val_accuracy: 0.6378
# Epoch 12/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6656 - accuracy: 0.6576 - val_loss: 0.6974 - val_accuracy: 0.6378
# Epoch 13/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.6654 - val_loss: 0.6886 - val_accuracy: 0.6339
# Epoch 14/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6598 - accuracy: 0.6595 - val_loss: 0.7052 - val_accuracy: 0.6417
# Epoch 15/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6628 - accuracy: 0.6615 - val_loss: 0.6849 - val_accuracy: 0.6378
# Epoch 16/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6651 - accuracy: 0.6673 - val_loss: 0.6773 - val_accuracy: 0.6339
# Epoch 17/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6547 - accuracy: 0.6615 - val_loss: 0.6694 - val_accuracy: 0.6378
# Epoch 18/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6511 - accuracy: 0.6595 - val_loss: 0.6625 - val_accuracy: 0.6378
# Epoch 19/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6473 - accuracy: 0.6595 - val_loss: 0.6559 - val_accuracy: 0.6378
# Epoch 20/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6451 - accuracy: 0.6576 - val_loss: 0.6678 - val_accuracy: 0.6378
# Epoch 21/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6431 - accuracy: 0.6634 - val_loss: 0.6529 - val_accuracy: 0.6339
# Epoch 22/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6634 - val_loss: 0.6574 - val_accuracy: 0.6378
# Epoch 23/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6443 - accuracy: 0.6615 - val_loss: 0.6525 - val_accuracy: 0.6378
# Epoch 24/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6396 - accuracy: 0.6576 - val_loss: 0.6510 - val_accuracy: 0.6378
# Epoch 25/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.6673 - val_loss: 0.6500 - val_accuracy: 0.6378
# Epoch 26/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.6673 - val_loss: 0.6493 - val_accuracy: 0.6378
# Epoch 27/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6673 - val_loss: 0.6579 - val_accuracy: 0.6339
# Epoch 28/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6351 - accuracy: 0.6634 - val_loss: 0.6483 - val_accuracy: 0.6378
# Epoch 29/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6673 - val_loss: 0.6510 - val_accuracy: 0.6417
# Epoch 30/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6306 - accuracy: 0.6693 - val_loss: 0.6537 - val_accuracy: 0.6457
# Epoch 31/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6290 - accuracy: 0.6790 - val_loss: 0.6553 - val_accuracy: 0.6417
# Epoch 32/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6262 - accuracy: 0.6809 - val_loss: 0.6563 - val_accuracy: 0.6417
# Epoch 33/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6294 - accuracy: 0.6868 - val_loss: 0.6455 - val_accuracy: 0.6496
# Epoch 34/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6266 - accuracy: 0.6868 - val_loss: 0.6474 - val_accuracy: 0.6496
# Epoch 35/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6234 - accuracy: 0.6848 - val_loss: 0.6451 - val_accuracy: 0.6339
# Epoch 36/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6240 - accuracy: 0.6848 - val_loss: 0.6423 - val_accuracy: 0.6417
# Epoch 37/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6202 - accuracy: 0.6751 - val_loss: 0.6494 - val_accuracy: 0.6417
# Epoch 38/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6213 - accuracy: 0.6770 - val_loss: 0.6410 - val_accuracy: 0.6339
# Epoch 39/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6190 - accuracy: 0.6809 - val_loss: 0.6478 - val_accuracy: 0.6339
# Epoch 40/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6153 - accuracy: 0.6809 - val_loss: 0.6430 - val_accuracy: 0.6339
# Epoch 41/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.6770 - val_loss: 0.6466 - val_accuracy: 0.6220
# Epoch 42/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6106 - accuracy: 0.6809 - val_loss: 0.6483 - val_accuracy: 0.6220
# Epoch 43/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6115 - accuracy: 0.6770 - val_loss: 0.6469 - val_accuracy: 0.6220
# Epoch 44/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6096 - accuracy: 0.6790 - val_loss: 0.6414 - val_accuracy: 0.6339
# Epoch 45/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6102 - accuracy: 0.6809 - val_loss: 0.6394 - val_accuracy: 0.6378
# Epoch 46/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.6751 - val_loss: 0.6441 - val_accuracy: 0.6378
# Epoch 47/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6048 - accuracy: 0.6790 - val_loss: 0.6378 - val_accuracy: 0.6378
# Epoch 48/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6042 - accuracy: 0.6770 - val_loss: 0.6418 - val_accuracy: 0.6378
# Epoch 49/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6021 - accuracy: 0.6848 - val_loss: 0.6393 - val_accuracy: 0.6378
# Epoch 50/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6029 - accuracy: 0.6829 - val_loss: 0.6364 - val_accuracy: 0.6417
# Epoch 51/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5978 - accuracy: 0.6946 - val_loss: 0.6364 - val_accuracy: 0.6417
# Epoch 52/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.6829 - val_loss: 0.6302 - val_accuracy: 0.6496
# Epoch 53/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.6829 - val_loss: 0.6263 - val_accuracy: 0.6457
# Epoch 54/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.6887 - val_loss: 0.6239 - val_accuracy: 0.6654
# Epoch 55/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5966 - accuracy: 0.7023 - val_loss: 0.6400 - val_accuracy: 0.6535
# Epoch 56/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.6868 - val_loss: 0.6310 - val_accuracy: 0.6496
# Epoch 57/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5947 - accuracy: 0.6907 - val_loss: 0.6160 - val_accuracy: 0.6693
# Epoch 58/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5947 - accuracy: 0.6887 - val_loss: 0.6240 - val_accuracy: 0.6575
# Epoch 59/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5873 - accuracy: 0.6926 - val_loss: 0.6187 - val_accuracy: 0.6654
# Epoch 60/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5839 - accuracy: 0.6946 - val_loss: 0.6111 - val_accuracy: 0.6811
# Epoch 61/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5819 - accuracy: 0.7004 - val_loss: 0.6109 - val_accuracy: 0.6732
# Epoch 62/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5849 - accuracy: 0.6984 - val_loss: 0.6052 - val_accuracy: 0.6811
# Epoch 63/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5820 - accuracy: 0.6946 - val_loss: 0.6056 - val_accuracy: 0.6811
# Epoch 64/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5770 - accuracy: 0.6984 - val_loss: 0.6015 - val_accuracy: 0.6772
# Epoch 65/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5789 - accuracy: 0.7043 - val_loss: 0.6086 - val_accuracy: 0.6772
# Epoch 66/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5796 - accuracy: 0.6984 - val_loss: 0.5984 - val_accuracy: 0.6929
# Epoch 67/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5728 - accuracy: 0.7121 - val_loss: 0.6656 - val_accuracy: 0.6732
# Epoch 68/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5923 - accuracy: 0.6907 - val_loss: 0.5992 - val_accuracy: 0.6732
# Epoch 69/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5751 - accuracy: 0.7062 - val_loss: 0.5929 - val_accuracy: 0.6890
# Epoch 70/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5709 - accuracy: 0.7004 - val_loss: 0.5951 - val_accuracy: 0.6969
# Epoch 71/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5731 - accuracy: 0.7082 - val_loss: 0.5977 - val_accuracy: 0.6969
# Epoch 72/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5618 - accuracy: 0.7121 - val_loss: 0.5923 - val_accuracy: 0.6850
# Epoch 73/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5601 - accuracy: 0.7121 - val_loss: 0.6136 - val_accuracy: 0.6772
# Epoch 74/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5648 - accuracy: 0.7198 - val_loss: 0.6021 - val_accuracy: 0.6654
# Epoch 75/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5602 - accuracy: 0.7121 - val_loss: 0.5969 - val_accuracy: 0.6811
# Epoch 76/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5581 - accuracy: 0.7101 - val_loss: 0.5953 - val_accuracy: 0.6890
# Epoch 77/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5558 - accuracy: 0.7140 - val_loss: 0.5939 - val_accuracy: 0.6811
# Epoch 78/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5627 - accuracy: 0.7082 - val_loss: 0.5858 - val_accuracy: 0.6850
# Epoch 79/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5511 - accuracy: 0.7296 - val_loss: 0.5882 - val_accuracy: 0.6890
# Epoch 80/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5501 - accuracy: 0.7160 - val_loss: 0.5826 - val_accuracy: 0.6969
# Epoch 81/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5515 - accuracy: 0.7121 - val_loss: 0.5843 - val_accuracy: 0.6969
# Epoch 82/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5502 - accuracy: 0.7160 - val_loss: 0.5904 - val_accuracy: 0.6772
# Epoch 83/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5515 - accuracy: 0.7218 - val_loss: 0.5810 - val_accuracy: 0.7126
# Epoch 84/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5517 - accuracy: 0.7257 - val_loss: 0.5783 - val_accuracy: 0.6811
# Epoch 85/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5524 - accuracy: 0.7101 - val_loss: 0.5799 - val_accuracy: 0.7008
# Epoch 86/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5483 - accuracy: 0.7296 - val_loss: 0.5759 - val_accuracy: 0.6732
# Epoch 87/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5442 - accuracy: 0.7101 - val_loss: 0.5760 - val_accuracy: 0.6811
# Epoch 88/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.7257 - val_loss: 0.6013 - val_accuracy: 0.6929
# Epoch 89/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.7257 - val_loss: 0.5819 - val_accuracy: 0.6850
# Epoch 90/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5446 - accuracy: 0.7276 - val_loss: 0.5833 - val_accuracy: 0.6890
# Epoch 91/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5384 - accuracy: 0.7257 - val_loss: 0.6194 - val_accuracy: 0.6654
# Epoch 92/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5435 - accuracy: 0.7276 - val_loss: 0.5726 - val_accuracy: 0.6969
# Epoch 93/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5419 - accuracy: 0.7179 - val_loss: 0.5749 - val_accuracy: 0.6850
# Epoch 94/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5360 - accuracy: 0.7335 - val_loss: 0.5778 - val_accuracy: 0.6811
# Epoch 95/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5359 - accuracy: 0.7374 - val_loss: 0.5801 - val_accuracy: 0.6929
# Epoch 96/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5418 - accuracy: 0.7198 - val_loss: 0.5749 - val_accuracy: 0.7008
# Epoch 97/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5377 - accuracy: 0.7198 - val_loss: 0.5684 - val_accuracy: 0.7008
# Epoch 98/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5324 - accuracy: 0.7257 - val_loss: 0.5810 - val_accuracy: 0.6614
# Epoch 99/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5339 - accuracy: 0.7160 - val_loss: 0.5627 - val_accuracy: 0.6890
# Epoch 100/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5287 - accuracy: 0.7257 - val_loss: 0.5673 - val_accuracy: 0.6969
# Epoch 101/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5298 - accuracy: 0.7315 - val_loss: 0.6280 - val_accuracy: 0.6890
# Epoch 102/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5458 - accuracy: 0.7179 - val_loss: 0.5642 - val_accuracy: 0.7087
# Epoch 103/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5253 - accuracy: 0.7315 - val_loss: 0.5641 - val_accuracy: 0.6969
# Epoch 104/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5274 - accuracy: 0.7296 - val_loss: 0.5625 - val_accuracy: 0.6732
# Epoch 105/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5274 - accuracy: 0.7412 - val_loss: 0.5631 - val_accuracy: 0.7008
# Epoch 106/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5205 - accuracy: 0.7374 - val_loss: 0.5923 - val_accuracy: 0.6772
# Epoch 107/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.7296 - val_loss: 0.5684 - val_accuracy: 0.6969
# Epoch 108/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.7393 - val_loss: 0.5648 - val_accuracy: 0.6969
# Epoch 109/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7315 - val_loss: 0.5654 - val_accuracy: 0.6890
# Epoch 110/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5177 - accuracy: 0.7354 - val_loss: 0.5658 - val_accuracy: 0.6929
# Epoch 111/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5200 - accuracy: 0.7374 - val_loss: 0.5632 - val_accuracy: 0.6890
# Epoch 112/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5196 - accuracy: 0.7471 - val_loss: 0.5636 - val_accuracy: 0.6811
# Epoch 113/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7354 - val_loss: 0.5630 - val_accuracy: 0.7008
# Epoch 114/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5253 - accuracy: 0.7335 - val_loss: 0.5601 - val_accuracy: 0.6890
# Epoch 115/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5185 - accuracy: 0.7432 - val_loss: 0.5581 - val_accuracy: 0.6969
# Epoch 116/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5147 - accuracy: 0.7393 - val_loss: 0.5583 - val_accuracy: 0.6969
# Epoch 117/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5182 - accuracy: 0.7257 - val_loss: 0.5632 - val_accuracy: 0.6890
# Epoch 118/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.7432 - val_loss: 0.5681 - val_accuracy: 0.6850
# Epoch 119/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.7374 - val_loss: 0.5597 - val_accuracy: 0.7008
# Epoch 120/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5132 - accuracy: 0.7412 - val_loss: 0.5660 - val_accuracy: 0.6929
# Epoch 121/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5060 - accuracy: 0.7412 - val_loss: 0.5961 - val_accuracy: 0.6693
# Epoch 122/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5204 - accuracy: 0.7490 - val_loss: 0.5686 - val_accuracy: 0.7047
# Epoch 123/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5173 - accuracy: 0.7335 - val_loss: 0.5555 - val_accuracy: 0.7087
# Epoch 124/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5080 - accuracy: 0.7568 - val_loss: 0.5595 - val_accuracy: 0.6969
# Epoch 125/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.7393 - val_loss: 0.5518 - val_accuracy: 0.7008
# Epoch 126/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5075 - accuracy: 0.7510 - val_loss: 0.5625 - val_accuracy: 0.7047
# Epoch 127/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7529 - val_loss: 0.5517 - val_accuracy: 0.7126
# Epoch 128/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5055 - accuracy: 0.7568 - val_loss: 0.5573 - val_accuracy: 0.7008
# Epoch 129/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5026 - accuracy: 0.7510 - val_loss: 0.5536 - val_accuracy: 0.6890
# Epoch 130/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5099 - accuracy: 0.7529 - val_loss: 0.5516 - val_accuracy: 0.7087
# Epoch 131/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7588 - val_loss: 0.5491 - val_accuracy: 0.7047
# Epoch 132/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4995 - accuracy: 0.7568 - val_loss: 0.5963 - val_accuracy: 0.6929
# Epoch 133/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5048 - accuracy: 0.7529 - val_loss: 0.5563 - val_accuracy: 0.7008
# Epoch 134/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5038 - accuracy: 0.7607 - val_loss: 0.5450 - val_accuracy: 0.7087
# Epoch 135/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5049 - accuracy: 0.7588 - val_loss: 0.5587 - val_accuracy: 0.7047
# Epoch 136/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4968 - accuracy: 0.7588 - val_loss: 0.5821 - val_accuracy: 0.6929
# Epoch 137/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4999 - accuracy: 0.7646 - val_loss: 0.6021 - val_accuracy: 0.6772
# Epoch 138/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5284 - accuracy: 0.7451 - val_loss: 0.5490 - val_accuracy: 0.6850
# Epoch 139/150
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7510 - val_loss: 0.5446 - val_accuracy: 0.6890
# Epoch 140/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4997 - accuracy: 0.7568 - val_loss: 0.5455 - val_accuracy: 0.6969
# Epoch 141/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5058 - accuracy: 0.7568 - val_loss: 0.5432 - val_accuracy: 0.6890
# Epoch 142/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.4991 - accuracy: 0.7568 - val_loss: 0.5570 - val_accuracy: 0.6969
# Epoch 143/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7471 - val_loss: 0.5468 - val_accuracy: 0.6890
# Epoch 144/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5041 - accuracy: 0.7568 - val_loss: 0.5656 - val_accuracy: 0.6969
# Epoch 145/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.7529 - val_loss: 0.5411 - val_accuracy: 0.7087
# Epoch 146/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7685 - val_loss: 0.5476 - val_accuracy: 0.7047
# Epoch 147/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5013 - accuracy: 0.7665 - val_loss: 0.5421 - val_accuracy: 0.6890
# Epoch 148/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7626 - val_loss: 0.5534 - val_accuracy: 0.6929
# Epoch 149/150
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4925 - accuracy: 0.7646 - val_loss: 0.5383 - val_accuracy: 0.6969
# Epoch 150/150
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.7568 - val_loss: 0.5354 - val_accuracy: 0.7087

# %% [markdown]
# #Manual k-Fold Cross Validation
# The gold standard for machine learning model evaluation is k-fold cross validation.
#
# It provides a robust estimate of the performance of a model on unseen data. It does this by splitting the training dataset into k subsets, taking turns training models on all subsets except one, which is held out, and evaluating model performance on the held-out validation dataset. The process is repeated until all subsets are given an opportunity to be the held-out validation set. The performance measure is then averaged across all models that are created.
#
# It is important to understand that cross validation means estimating a model design (e.g., 3-layer vs. 4-layer neural network) rather than a specific fitted model. You do not want to use a specific dataset to fit the models and compare the result since this may be due to that particular dataset fitting better on one model design. Instead, you want to use multiple datasets to fit, resulting in multiple fitted models of the same design, taking the average performance measure for comparison.
#
# Cross validation is often not used for evaluating deep learning models because of the greater computational expense. For example, k-fold cross validation is often used with 5 or 10 folds. As such, 5 or 10 models must be constructed and evaluated, significantly adding to the evaluation time of a model.
#
# Nevertheless, when the problem is small enough or if you have sufficient computing resources, k-fold cross validation can give you a less-biased estimate of the performance of your model.
#
# In the example below, you will use the handy StratifiedKFold class from the scikit-learn Python machine learning library to split the training dataset into 10 folds. The folds are stratified, meaning that the algorithm attempts to balance the number of instances of each class in each fold.
#
# The example creates and evaluates 10 models using the 10 splits of the data and collects all the scores. The verbose output for each epoch is turned off by passing verbose=0 to the fit() and evaluate() functions on the model.
#
# The performance is printed for each model, and it is stored. The average and standard deviation of the model performance are then printed at the end of the run to provide a robust estimate of model accuracy.

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy as np
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
for train, test in kfold.split(X, Y):
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# Fit the model
	model.fit(X[train], Y[train], epochs=150, batch_size=10, verbose=0)
	# evaluate the model
	scores = model.evaluate(X[test], Y[test], verbose=0)
	print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
	cvscores.append(scores[1] * 100)

print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# accuracy: 75.32%
# accuracy: 75.32%
# accuracy: 67.53%
# WARNING:tensorflow:5 out of the last 3910 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6fda2504c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# accuracy: 64.94%
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6fda129dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# accuracy: 70.13%
# accuracy: 66.23%
# accuracy: 80.52%
# accuracy: 72.73%
# accuracy: 73.68%
# accuracy: 82.89%
# 72.93% (+/- 5.61%)
